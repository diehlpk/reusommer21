# %%
import numpy as np
import matplotlib.pyplot as plt

pgf_with_latex = {"text.usetex": True, "font.size" : 12, "pgf.preamble" : [r'\usepackage{xfrac}'] }

# %% [markdown]
# ## Comparison of the three methods

# %%
con_vhcm_n = np.genfromtxt('con_vhcm_n.csv',delimiter=',')
con_mscm_n = np.genfromtxt('con_mscm_n.csv',delimiter=',')
con_mdcm_n = np.genfromtxt('con_mdcm_n.csv',delimiter=',')

# %%
x = np.linspace(0,1,len(con_vhcm_n))

# %%
plt.plot(x,con_mdcm_n,label="MDCM",c="black",marker="s")
plt.plot(x,con_mscm_n,label="MSCM",c="black",marker="o")
plt.plot(x,con_vhcm_n,label="VHCM",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Mixed boundary conditions \n Quadratic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["1/8","1/16","1/32","1/64"])
plt.savefig("Condition-n.pdf",bbox_inches='tight')

# %%
con_vhcm_n = np.genfromtxt('con_vhm_d.csv',delimiter=',')
con_mscm_n = np.genfromtxt('con_mscm_d.csv',delimiter=',')
con_mdcm_n = np.genfromtxt('con_mdcm_d.csv',delimiter=',')

# %%
plt.plot(x,con_mdcm_n,label="MDCM",c="black",marker="s")
plt.plot(x,con_mscm_n,label="MSCM",c="black",marker="o")
plt.plot(x,con_vhcm_n,label="VHCM",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Homogeneous Dirichlet boundary conditions \n Quadratic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["1/8","1/16","1/32","1/64"])
plt.savefig("Condition-d.pdf",bbox_inches='tight')

# %% [markdown]
# ## MDCM with cubic interpolation

# %%
con_mdcm_d_n_m = np.genfromtxt('con_mdcm_d-cubic-non-matching.csv',delimiter=',')
con_mdcm_d_m = np.genfromtxt('con_mdcm_d-cubic-matching.csv',delimiter=',')
con_mdcm_d = np.genfromtxt('con_mdcm_d-cubic.csv',delimiter=',')

# %%
#plt.plot(x,con_mdcm_d,label="Matching endpoint - $h_{PD}=h_{FD}/2$",c="black",marker="s")
plt.plot(x,con_mdcm_d_m,label="Matching endpoint",c="black",marker="o")
plt.plot(x,con_mdcm_d_n_m,label="Non-matching endpoint$",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Homogeneous Dirichlet boundary conditions \n Cubic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["2/25","1/15","2/35","1/10"])
plt.savefig("Condition-d-cubic.pdf",bbox_inches='tight')

# %%
con_mdcm_d_n_m = np.genfromtxt('con_mdcm_n-cubic-non-matching.csv',delimiter=',')
con_mdcm_d_m = np.genfromtxt('con_mdcm_n-cubic-matching.csv',delimiter=',')
con_mdcm_d = np.genfromtxt('con_mdcm_n-cubic.csv',delimiter=',')

# %%
#plt.plot(x,con_mdcm_d,label="Matching endpoint - $h_{PD}=h_{FD}/2$",c="black",marker="s")
plt.plot(x,con_mdcm_d_m,label="Matching endpoint",c="black",marker="o")
plt.plot(x,con_mdcm_d_n_m,label="Non-matching endpoint$",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Mixed boundary conditions \n Cubic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["2/25","1/15","2/35","1/10"])
plt.savefig("Condition-n-cubic.pdf",bbox_inches='tight')

# %% [markdown]
# ## MDCM with quadratic interpolation

# %%
con_mdcm_d_n_m = np.genfromtxt('con_mdcm_n-quadratic-non-matching.csv',delimiter=',')
con_mdcm_d_m = np.genfromtxt('con_mdcm_n-quadratic-matching.csv',delimiter=',')
#con_mdcm_d = np.genfromtxt('con_mdcm_d-cubic.csv',delimiter=',')

# %%
#plt.plot(x,con_mdcm_d,label="Matching endpoint - $h_{PD}=h_{FD}/2$",c="black",marker="s")
plt.plot(x,con_mdcm_d_m,label="Matching endpoint",c="black",marker="o")
plt.plot(x,con_mdcm_d_n_m,label="Non-matching endpoint",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Mixed boundary conditions \n Quadratic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["2/25","1/15","2/35","1/10"])
plt.savefig("Condition-n-quadratic.pdf",bbox_inches='tight')

# %%
con_mdcm_d_n_m = np.genfromtxt('con_mdcm_d-quadratic-non-matching.csv',delimiter=',')
con_mdcm_d_m = np.genfromtxt('con_mdcm_d-quadratic-matching.csv',delimiter=',')
#con_mdcm_d = np.genfromtxt('con_mdcm_d-cubic.csv',delimiter=',')

# %%
#plt.plot(x,con_mdcm_d,label="Matching endpoint - $h_{PD}=h_{FD}/2$",c="black",marker="s")
plt.plot(x,con_mdcm_d_m,label="Matching endpoint",c="black",marker="o")
plt.plot(x,con_mdcm_d_n_m,label="Non-matching endpoin$",c="black",marker="x")
plt.grid()
plt.xlabel("$\delta$")
plt.ylabel("Condition number")
plt.yscale('log')
plt.legend()
plt.title("Homogeneous Dirichlet boundary conditions \n Quadratic interpolation")
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(["2/25","1/15","2/35","1/10"])
plt.savefig("Condition-d-quadratic.pdf",bbox_inches='tight')
